# %%
import pandas as pd

import sys
sys.path.append('../utilities')
from backtest_functions_v2 import *

# %% [markdown]
# ### daily

# %%
df = pd.read_parquet('../bitcoin_historical_price/btcusd_daily_price.parquet')
df = df[df.index >= '2024-01-01']
df = df[df.index < '2025-01-01']
df['signal'] = 1
run_backtest(df)
# Out:
# Overall Annual Return: 118.43%
# Overall Annual Sharpe Ratio: 1.7741
# Maximum Drawdown: -27.2 %
# Alpha: 0.0
# Beta: 1.0
#
# Yearly Metrics:
#    year  yearly_return  yearly_std  yearly_beta  yearly_alpha  yearly_sharpe
# 0  2024       1.184281     0.51485          1.0           0.0       1.774104

# %% [markdown]
# ### hour

# %%
df = pd.read_parquet("../bitcoin_historical_price/btcusd_hourly_price.parquet")
df = df[df.index >= '2024-01-01']
df = df[df.index < '2025-01-01']
df['signal'] = 1
run_backtest(df, freq='h')
# Out:
# Overall Annual Return: 120.69%
# Overall Annual Sharpe Ratio: 1.7644
# Maximum Drawdown: -32.33 %
# Alpha: 0.0
# Beta: 1.0
#
# Yearly Metrics:
#    year  yearly_return  yearly_std  yearly_beta  yearly_alpha  yearly_sharpe
# 0  2024       1.206942    0.527597          1.0           0.0       1.764392

# %% [markdown]
# ### 15 minute

# %%
df = pd.read_parquet("../bitcoin_historical_price/btcusd_15min_price.parquet")
df = df[df.index >= '2024-01-01']
df = df[df.index < '2025-01-01']
df['signal'] = 1
run_backtest(df, freq='15min')
# Out:
# Overall Annual Return: 118.53%
# Overall Annual Sharpe Ratio: 1.7436
# Maximum Drawdown: -32.44 %
# Alpha: 0.0
# Beta: 1.0
#
# Yearly Metrics:
#    year  yearly_return  yearly_std  yearly_beta  yearly_alpha  yearly_sharpe
# 0  2024       1.185282    0.528534          1.0           0.0       1.743577
