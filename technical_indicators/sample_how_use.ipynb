# %%
import pandas as pd

import sys
sys.path.append('../utilities')
from backtest_functions_v2 import *

# %% [markdown]
# ### daily

# %%
df = pd.read_parquet('../bitcoin_historical_price/btcusd_daily_price.parquet')
df = df[df.index >= '2024-01-01']
df = df[df.index < '2025-01-01']
df['signal'] = 1
run_backtest(df)
# Out:
# Overall Annual Return: 116.14%
# Overall Annual Sharpe Ratio: 2.203
# Maximum Drawdown: -27.2 %
# Win/Loss Ratio: 1.1488
# Alpha: 0.0
# Beta: 1.0
#
# Yearly Metrics:
#    year  yearly_return  yearly_std  yearly_beta  yearly_alpha  yearly_sharpe
# 0  2024       1.161363    0.527168          1.0           0.0       2.203024

# %% [markdown]
# ### hour

# %%
df = pd.read_parquet("../bitcoin_historical_price/btcusd_hourly_price.parquet")
df = df[df.index >= '2024-01-01']
df = df[df.index < '2025-01-01']
df['signal'] = 1
run_backtest(df, freq='hourly')
# Out:
# Overall Annual Return: 118.79%
# Overall Annual Sharpe Ratio: 2.2902
# Maximum Drawdown: -32.33 %
# Win/Loss Ratio: 1.0577
# Alpha: 0.0
# Beta: 1.0
#
# Yearly Metrics:
#    year  yearly_return  yearly_std  yearly_beta  yearly_alpha  yearly_sharpe
# 0  2024       1.187879    0.518675          1.0           0.0       2.290219

# %% [markdown]
# ### minute

# %%
df = pd.read_parquet("../bitcoin_historical_price/btcusd_minute_price.parquet")
df = df[df.index >= '2024-01-01']
df = df[df.index < '2025-01-01']
df['signal'] = 1
run_backtest(df, freq='minute')
# Out:
# Overall Annual Return: 162.37%
# Overall Annual Sharpe Ratio: 2.7365
# Maximum Drawdown: -32.8 %
# Win/Loss Ratio: 1.0102
# Alpha: 0.0
# Beta: 1.0
#
# Yearly Metrics:
#    year  yearly_return  yearly_std  yearly_beta  yearly_alpha  yearly_sharpe
# 0  2024        1.62372    0.593351          1.0           0.0       2.736526
